# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = []
for l in os.listdir('viz'):
    losses.append(float(l[:-4]))

# %%
len(losses)
# Out:
# 500

# %%
plt.hist(losses, bins = 50)
 
# Show plot
plt.title('Loss Distribution over Test Dataset')
plt.show()
